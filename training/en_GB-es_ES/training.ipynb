# %%
import os
import torch
import random
import datasets

import numpy as np
import pandas as pd

from tqdm.auto import tqdm
from datetime import datetime
from transformers import AdamW
from transformers import get_scheduler
from torch.utils.data import DataLoader
from IPython.display import display, HTML
from datasets import Dataset, DatasetDict, load_dataset, load_metric
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
def process_data():
    """
    Output: Translated text of the source text
    :param src_text: source string
    """ 
    
    #Load data (needs to be changed to loading from BQ or bucket)
    df = pd.read_csv('../../data/en_GB-es_ES/en_GB-es_ES_batch_0.csv', engine='python')

    df = df[['source', 'target']] # will be redundent when setup 
    df['source'] = df['source'].apply(lambda s: str(s))
    df['target'] = df['target'].apply(lambda s: str(s))

    # Transform to HuggingFace Dataset
    data = Dataset.from_pandas(pd.DataFrame({'translation': df.to_dict('records')})) 

    # Split data into training sets
    train_test_valid = data.train_test_split(shuffle=True, seed=7, test_size=0.02)
    test_valid = train_test_valid['test'].train_test_split(shuffle=True, seed=7, test_size=0.5)

    # Convert to train/validate/test
    dataset = DatasetDict({
        'train': train_test_valid['train'],
        'validation': test_valid['test'],
        'test': test_valid['train']})
     
    return dataset

# %%
def tokenization_processing(dataset, source_len=128, target_len=128,
                            source="source", target="target"):
    """
    Output: Generates tokenized data using the attributes of the base model
    :param dataset: raw dataset to transform
    :param source_len: maximum sentence length for source string
    :param target_len: maximum sentence length for target string
    :param source: source language
    :param target: target language
    """
    
    inputs = [s[source] for s in dataset["translation"]]
    targets = [s[target] for s in dataset["translation"]]
    
    model_inputs = tokenizer(inputs, max_length=source_len, truncation=True)
    
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=target_len, truncation=True)
        
    model_inputs["labels"] = labels["input_ids"]
    
    return model_inputs

# %%
def compute_metrics(predictions): # n.b. can add more metrics later
    """
    Output: evaluation metrics to track model performance in training
    :param predictions: output of predictions to decode
    """
    
    metric = load_metric("sacrebleu")
    
    def process_text(predictions, labels):
        preds = [pred.strip() for pred in predictions]
        labels = [[label.strip()] for label in labels]
        return preds, labels
    
    preds, labels = predictions
    
    if isinstance(preds, tuple):
        preds = preds[0]
    
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = process_text(decoded_preds, decoded_labels)
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    
    result = {k: round(v, 6) for k, v in result.items()} #round results
    
    return result

# %%
model_name="Helsinki-NLP/opus-mt-en-es"

dataset = process_data()

print('load models and data collator')
trained_model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=trained_model)
# Out:
# load models and data collator

# %%
tokenized_dataset = dataset.map(tokenization_processing, batched=True)
# Out:
#   0%|          | 0/211 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
tokenized_dataset['validation']['translation']
# Out:
# [{'source': 'Non-binary', 'target': 'No binario'},
#  {'source': '“I saw us writing a PowerPoint presentation, and I had the fear that it would be a PowerPoint slide battle.',
#   'target': '"Pensé en la idea de crear un PowerPoint y me daba miedo que la presentación consistiese únicamente en pasar diapositivas.'},
#  {'source': 'Jin', 'target': 'Jin'},
#  {'source': 'Who designed the range?', 'target': '¿Quién diseñó la serie?'},
#  {'source': 'Display techniques linked to range presentation media',
#   'target': 'Técnicas de exposición relacionadas con los medios de presentación del surtido'},
#  {'source': 'or that could be given a new life or function.',
#   'target': 'o que puedan tener una nueva vida o función.'},
#  {'source': 'Actually, no one is right.',
#   'target': 'En realidad, nadie tiene razón.'},
#  {'source': 'Which is why you play a vital role in helping your store keep its ASC/MSC certification.',
#   'target': 'Por esta razón, desempeñas un papel fundamental para ayudar a tu tienda a mantener su certificación ASC/MSC.'},
#  {'source': '"How can this space live andwhat is the right life for these people?"',
#   'target': '"¿Cómo se puede vivir aquí ycuál es la mejor vida para estas personas?".'},
#  {'source': 'Openness', 'target': 'Sinceridad'},
#  {'source': 'Preparing for action: In this lesson, you will be introduced to the Purpose Impact Project – what it is, examples, the framework, and next steps – in preparation for Session 2. ',
#   'target': 'Pasar a la acción: en esta lección os presentaremos el Proyecto de impacto (qué es, ejemplos, marco y próximos pasos) para prepararos para la sesión 2. '},
#  {'source': 'Our big IKEA community, strong culture and values form the foundations, and we are optimistic of what is to come.',
#   'target': 'Nuestra gran comunidad IKEA, además de la cultura y los valores sólidos que la permean, sientan las bases, y nos mostramos optimistas ante lo que está por venir.'},
#  {'source': 'Different wall materials require different types of fixing devices.',
#   'target': 'Las fijaciones dependen del material de la pared.'},
#  {'source': 'We’ve been leading up to this moment, and I hope you’re as inspired as I am.',
#   'target': 'Todo lo que hemos hecho nos ha dirigido a este momento y espero que os inspire tanto como a mí.'},
#  {'source': 'Together, they will have agreed on the overall sales ambition for your country, and secured the supply through communications throughout the value chain.',
#   'target': 'Juntos, habrán acordado la ambición general de ventas a nivel nacional y habrán asegurado el suministro a través de las comunicaciones en toda la cadena de valor.'},
#  {'source': 'Eager to deliver customer value and to deliver excellence in operation within a fast-paced supply chain environment.',
#   'target': 'Deseos de ofrecer valor al cliente y excelencia en las operaciones, en un entorno de un ritmo acelerado en el ámbito de la cadena de suministro.'},
#  {'source': "Scenario 5MarchYou're attending the Commercial Team meeting when the Store Manager makes an announcement:",
#   'target': 'Situación 5MarzoEstás en una reunión con el Commercial Team cuando el jefe de tienda anuncia lo siguiente:'},
#  {'source': 'ReTuna Återbruksgalleria is a recycling mall, revolutionizing shopping in a climate-smart way.',
#   'target': 'ReTuna Återbruksgalleria es un centro comercial de reciclaje que ha revolucionado la forma en la que compramos para que sea más sostenible con el medioambiente.'},
#  {'source': 'Think about what risks there are in each of the areas marked on the pictures.',
#   'target': 'Piensa en los riesgos que hay en cada una de las áreas marcadas en las imágenes.'},
#  {'source': 'A sun lounger has cushions and a multicolour GRUCKAN bath towel on it.',
#   'target': 'Una tumbona tiene cojines y una toalla de baño GRUCKAN multicolor.'},
#  {'source': 'DATE OF FOUNDATION', 'target': 'FECHA DE FUNDACIÓN'},
#  {'source': 'An organised fridge with a fresh twist',
#   'target': 'Un frigorífico organizado con un toque de frescura'},
#  {'source': 'IKEA Bratislava helps its city set up 30 homes for homeless people in Slovakia',
#   'target': 'IKEA Bratislava colabora en el acondicionamiento de 30 hogares para personas sin techo de Eslovaquia'},
#  {'source': 'Workspace with hanging platters with plants, hung on ceiling, desk, carafe with stopper, laptop, glasses, two people talking.',
#   'target': 'Espacio de trabajo con bandejas con plantas colgadas en el techo, un escritorio, una botella con tapón, un portátil, vasos y dos personas hablando.'},
#  {'source': 'Think to yourself, how can this feedback help me?',
#   'target': 'Pensad en qué os puede ayudar este feedback.'},
#  {'source': 'High beds and the upper bed of bunk or loft beds are not suitable for children aged how many years due to the risk of injury from falls?',
#   'target': '¿Para niños de qué edad no son adecuadas las camas altas y la cama superior de literas debido al riesgo de lesiones por caídas?'},
#  {'source': 'Produced out of synthetic fibres so that it is easy to care for.',
#   'target': 'Fabricada con fibras sintéticas que garantizan un fácil mantenimiento.'},
#  {'source': 'and of course I want to be here.',
#   'target': 'y por supuesto quiero estar aquí.'},
#  {'source': 'So here’s what the jury will consider to identify and select winning ideas:',
#   'target': 'Así que esto es lo que el jurado considerará para seleccionar y decidir qué ideas serán las ganadoras:'},
#  {'source': 'After the introductory presentation, their CEO asks:',
#   'target': 'Tras la presentación introductoria, la directora general pregunta:'},
#  {'source': 'TROTTEN system.', 'target': 'Sistema TROTTEN.'},
#  {'source': 'collaboration, and continuous improvement which prepares the whole value chain and ensures',
#   'target': 'la colaboración y la mejora continua que preparan a toda la cadena de valor y'},
#  {'source': 'High frame with six shelvesClips to connect to other frames, and grooves for hooksHeight: 72"Depth: 12"Width: 12"',
#   'target': 'Estructura alta con seis estantesClips para conectarla a otras estructuras y ranuras para los ganchosAltura: 72" (2\xa0m)Profundidad: 12" (30\xa0cm)Anchura: 12" (30\xa0cm)'},
#  {'source': 'Combine the drawers with organisers from the IKEA range.',
#   'target': 'Combina los cajones con organizadores del surtido IKEA.'},
#  {'source': 'Small balls of merino wool.',
#   'target': 'Bolitas de lana merina.'},
#  {'source': 'TOFTAN is a low price family.',
#   'target': 'TOFTAN es una serie de precios bajos.'},
#  {'source': 'in your interviews moving forward.',
#   'target': 'en tus entrevistas a partir de ahora.'},
#  {'source': 'Being careful with resources is a core value at IKEA, and even though food waste accounts for a small proportion of our total footprint, it’s important that we scrutinise our business at every angle and take action where we can to reduce our climate footprint and improve our ways of working.',
#   'target': 'Ser cuidadosos con los recursos es un valor fundamental en IKEA, y aunque el desperdicio de alimentos representa una pequeña proporción de nuestra huella total, es importante que analicemos nuestro negocio desde todos los ángulos y tomemos las medidas que podamos para reducir nuestra huella climática y mejorar nuestra manera de trabajar.'},
#  {'source': 'The world is evolving and', 'target': 'El mundo evoluciona'},
#  {'source': "A range that's too small does not givecustomers enough choices.",
#   'target': 'Un surtido demasiado pequeñono ofrece suficientes opciones.'},
#  {'source': 'See more decoration products',
#   'target': 'Ver más productos de decoración'},
#  {'source': 'Since September 2021, we have already opened 16 new stores, shops and plan and order points, with more planned.',
#   'target': 'Desde septiembre de 2021, hemos inaugurado 16 nuevas tiendas y puntos de planificación y pedidos, y tenemos más aperturas previstas.'},
#  {'source': 'We can improve air quality almost instantly, with coordinated action, political will and behaviour changes across society.',
#   'target': 'Podemos mejorar la calidad del aire casi al instante, con acciones coordinadas, voluntad política y cambios de comportamiento en toda la sociedad.'},
#  {'source': 'was updated only every three hours.',
#   'target': 'se actualizaban solo cada tres horas.'},
#  {'source': 'HFB 17Outdoor livingSUMMER LAUNCH',
#   'target': 'HFB 17ExterioresLANZAMIENTO PARA EL VERANO'},
#  {'source': 'What is included in the VINDUM family?',
#   'target': '¿Qué incluye la serie VINDUM?'},
#  {'source': 'Airports are huge', 'target': 'Los aeropuertos son enormes'},
#  {'source': 'It is the same for\xa0everyone!',
#   'target': '¡Es igual para todos!'},
#  {'source': 'Design your own KALLAX storage',
#   'target': 'Diseña tu propio sistema de almacenaje KALLAX'},
#  {'source': 'MPP', 'target': 'MPP'},
#  {'source': 'The receiving unit is responsible to store the goods in the correct temperature in order to prevent any further damages.',
#   'target': 'La unidad de recepción es responsable de almacenar los productos a la temperatura correcta para evitar daños adicionales.'},
#  {'source': 'Content Language trainings in various languages are offered throughout IKEA depending on different needs.',
#   'target': 'Contenido En IKEA se imparten sesiones de formación en varios idiomas en función de diversas necesidades.'},
#  {'source': 'Now to understand', 'target': 'Para entender'},
#  {'source': 'CONSUMER PERCEPTION', 'target': 'PERCEPCIÓN DE LOS CONSUMIDORES'},
#  {'source': "When you're cooking up a storm in the kitchen, keep all your tools and tricks of the trade nearby with a handy trolley.",
#   'target': 'Cuando estés preparando la comida en la cocina, te será muy útil tener a mano todos tus utensilios en un práctico carrito.'},
#  {'source': 'The traditional look of the INGATORP is expressed through its great attention to detail, and features in key characteristics like turned legs.',
#   'target': 'La mesa INGATORP es de estilo clásico y presenta gran atención a los detalles, como sus patas torneadas, que son una característica clave.'},
#  {'source': 'Do: Ask, “What if I want to improve my self-leadership skills?”',
#   'target': 'Haz lo siguiente: Pregunta “¿Y si quiero mejorar mis habilidades de autoliderazgo?”.'},
#  {'source': 'But it is a team effort\u2028and a fair bit of luck involved as well.',
#   'target': 'Pero también el esfuerzo del equipo\u2028y un poco de suerte.'},
#  {'source': 'They are water repellent.', 'target': 'Son impermeables.'},
#  {'source': 'Personalise your profile', 'target': 'Personaliza tu perfil'},
#  {'source': 'V.1.3 - 2021', 'target': 'V.1.3 - 2021'},
#  {'source': 'Which products would the POKAL family work well with?',
#   'target': '¿Con qué productos combina bien la serie POKAL?'},
#  {'source': 'There any many benefits and improvements in the new approach with Financial Services, for you as a co-worker, e.g.:',
#   'target': 'El nuevo enfoque de los servicios financieros tiene muchas ventajas y mejoras para ti como colaborador/a, por ejemplo:'},
#  {'source': 'The Wola Park Community ShareSpace, near the city center of Warsaw, Poland, just opened its doors to the bustling residential area.',
#   'target': 'El Community ShareSpace del Wola Park, ubicado cerca del centro de la ciudad polaca de Varsovia, acaba de inaugurarse en una zona residencial bastante bulliciosa.'},
#  {'source': 'Why do visitors prefer our meeting places over others?',
#   'target': '¿Por qué los visitantes prefieren nuestros centros comerciales a otros?'},
#  {'source': 'A boy standing on a stool tends to a SKÅDIS pegboard combination hung over a white PÅHL desk in a green and blue room.',
#   'target': 'Un niño de pie sobre un taburete trata de alcanzar una combinación de tableros perforados SKÅDIS colgada sobre un escritorio PÅHL blanco en una habitación verde y azul.'},
#  {'source': 'Meet and mix in style', 'target': 'Combinaciones con estilo'},
#  {'source': 'Having been together for 20 years, they have built up a trust that allows them to have weeks where they don’t get as much done due to work or other activities.',
#   'target': 'En sus 20 años de relación han conseguido construir una confianza que les permite organizarse de forma que uno pueda hacer menos tareas en casa si alguna semana está muy ocupado con el trabajo u otras actividades,'},
#  {'source': 'Each box can be completed with a lid for stacking.',
#   'target': 'Puedes completar las cajas con una tapa y apilarlas.'},
#  {'source': 'Seat cushions are filled with wool.',
#   'target': 'Los cojines de los asientos están rellenos de lana.'},
#  {'source': 'If that’s the case, use the two-stepmethod again, but this time in reverse.That means you need to place the unit load further forward on the fork arms before being able to place it.',
#   'target': 'Si es el caso, usa de nuevo el método en 2 pasos, pero a la inversa.Eso significa que tendrás que colocar el pallet en la parte delantera de las horquillas antes de poder ubicarlo en su sitio.'},
#  {'source': 'When it comes to setting the dinner table, aesthetics plays a key role in making guests feel welcomed.',
#   'target': 'A la hora de poner la mesa, la estética juega un papel fundamental para que los invitados se sientan bienvenidos.'},
#  {'source': 'In most cases closed questions begin with: do, would, are, will, if.',
#   'target': 'Las preguntas cerradas preguntan acerca de cuestiones muy concretas.'},
#  {'source': 'The playful result is named ‘Homemade Jingle’ which also serves as the new brand song for IKEA in Portugal.',
#   'target': 'Esta melodía tan peculiar se llama "Homemade Jingle", que también sirve como nueva canción de la marca para IKEA Portugal.'},
#  {'source': 'at the same time,\u2028we also work with quality.',
#   'target': 'Y también trabajamos con la calidad.'},
#  {'source': 'Participate!', 'target': '¡Participa!'},
#  {'source': 'VITVAL includes a bunk bed, loft bed (optional under bed) and desk.',
#   'target': 'VITVAL incluye una litera, una cama alta (cama supletoria opcional) y un escritorio.'},
#  {'source': 'Kitchen with a base cabinet for hob with white door, a fridge with three doors, two shelves, a shelf section, and a chair.',
#   'target': 'Cocina con un armario bajo para la placa con una puerta blanca, un frigorífico de tres puertas, dos estantes, una estantería y una silla.'},
#  {'source': 'and built locally?', 'target': 'y construyese localmente?'},
#  {'source': 'Playing with IKEA’s Gaming Range in Japan and Austria',
#   'target': 'El surtido de gaming IKEA triunfa en Japón y Austria'},
#  {'source': 'Mari Grönholm (kopia).jpg',
#   'target': 'Mari Grönholm (kopia).jpg'},
#  {'source': 'and you should find your own\u2028way of living.',
#   'target': 'y encontrar el modo de vida\u2028que más se adapte a su contexto.'},
#  {'source': 'Trousers hanging area', 'target': 'Zona para colgar pantalones'},
#  {'source': 'At home in Haridwar and further afield, Ridhima’s gentle, grassroots activism is turning ripples into waves. ',
#   'target': 'En su casa, en Haridwar, y más allá, el pacífico activismo de base de Ridhima está empezando a mover montañas. '},
#  {'source': '- Because they show us the gender pay situation as a whole.',
#   'target': '- Porque nos muestra la situación de la igualdad salarial entre géneros en su conjunto.'},
#  {'source': 'The Line Manager can review, discuss and adjust the group goals throughout the year based upon changing context, team and individual conversations.',
#   'target': 'El responsable puede revisar, comentar y ajustar los objetivos del grupo a lo largo del año en función del contexto cambiante, así como de las conversaciones individuales y de equipo.'},
#  {'source': 'Easy to buy without too many decisions',
#   'target': 'Fácil de comprar sin tomar demasiadas decisiones'},
#  {'source': '- A huge hand for IKEA Canada.\u2028- Great job.',
#   'target': '-Muy buen trabajo, IKEA Canadá.\u2028-Fantástico.'},
#  {'source': 'Perfect for the things you want to be able to reach from your bed.',
#   'target': 'Este diván con cajones es perfecto para tener tus cosas a mano desde la cama.'},
#  {'source': 'Refer to your buying guide for the specific maximum loads for different products.',
#   'target': 'Consulta la guía de compra para conocer las cargas máximas específicas de los diferentes productos.'},
#  {'source': 'GRILLSKÄR is a modular outdoor kitchen comprising of one barbeque unit, one sink unit and one preparation unit.',
#   'target': 'GRILLSKÄR es una cocina de exterior modular que consta de una unidad de barbacoa, una de fregadero y una de estantería o isla.'},
#  {'source': 'Click submit to go to the next benefit.',
#   'target': 'Haz clic en Enviar para ir a la ventaja siguiente.'},
#  {'source': 'What would be 2-3 possible reasons why a customer would decide to purchase a synthetic duvet instead of a feather-down duvet?',
#   'target': '¿Cuáles serían 2 o 3 razones posibles por las que un cliente decidiría comprar un edredón sintético en lugar de un edredón de plumas?'},
#  {'source': 'Activity 3: Explore the taps range',
#   'target': 'Actividad 3: Descubre el surtido de grifos'},
#  {'source': 'How do I recycle the filters?',
#   'target': '¿Cómo debo reciclar los filtros?'},
#  {'source': 'More people than ever are working or studying from home, often from small spaces, while also taking care of their children.',
#   'target': 'Nunca había habido tanta gente trabajando o estudiando desde casa, a menudo en espacios reducidos, muchos de ellos con niños a su cargo.'},
#  {'source': 'Performance can come without supervision.',
#   'target': 'Los resultados llegan solos.'},
#  {'source': 'FIXA stick on floor protectors.',
#   'target': 'Protectores autoadhesivos FIXA.'},
#  {'source': 'IKEA 365+ \t94', 'target': 'IKEA 365+ \t94'},
#  {'source': 'The purchase includes everything needed.',
#   'target': 'La compra incluye todo lo necesario.'},
#  {'source': 'Even with a little footprint, this studio apartment gives its creative resident all the space she needs to do the things she enjoys and house all the objects she loves.\u2028Come in and have a look.',
#   'target': 'Incluso con poco de espacio, la persona creativa que vive en este estudio tiene todo el espacio que necesita para hacer lo que le gusta y guardar los objetos que le encantan.\u2028Echa un vistazo.'},
#  {'source': 'BOLMEN includes a soap dish, mirror and towel rai.',
#   'target': 'BOLMEN incluye una jabonera, un espejo y un toallero.'},
#  {'source': 'See more duvets', 'target': 'Ver más edredones'},
#  {'source': 'See what products FunPlus used at the office',
#   'target': 'Descubre qué productos utilizó FunPlus para su oficina'},
#  {'source': 'will be plant-based as well.',
#   'target': 'también serán de origen vegetal.'},
#  {'source': 'Transparent Glass', 'target': 'Vidrio transparente'},
#  {'source': 'The wall fittings are not included.',
#   'target': 'Los herrajes de pared no están incluidos.'},
#  {'source': 'What temperature is the safety stop button set at?',
#   'target': '¿A qué temperatura está se activa el botón de seguridad del mezclador termostático?'},
#  {'source': 'North of the Yangtze River, which divides the Anhui Province in two, sits the province capital of Hefei.',
#   'target': 'Al norte del río Yangtsé, que divide la provincia de Anhui en dos, se encuentra su capital, Hefei.'},
#  {'source': 'In FY16, our total tax bill including other taxes and duties amounted to approximately EUR 1.9 billion.',
#   'target': 'El importe total de nuestros impuestos para el ejercicio 2016, incluyendo otros impuestos y aranceles, ascendió aproximadamente a 1 900 millones de euros.'},
#  {'source': 'for less than 60 euro', 'target': 'por menos de 60\xa0€'},
#  {'source': 'Businesses, big and small, NGOs, governments, activists, citizens – together we have it in our hands to change the direction of the climate crisis and use the recovery from COVID-19 to build back better and create the future we want to be part of.',
#   'target': 'Los pequeños y grandes negocios, las ONG, los Gobiernos, los activistas y la ciudadanía en su conjunto deben colaborar para cambiar la dirección de la crisis climática y aprovechar la recuperación de la COVID-19 para salir reforzados y crear un futuro del que todos queramos formar parte.'},
#  {'source': "Before I get to you –\u2028and I can see you're fishing there.",
#   'target': 'Antes de mencionarte a ti,\u2028que veo que ya estás lanzando la caña...'},
#  {'source': "From 'I'm just looking'",
#   'target': 'Pasar del «solo estaba mirando»'},
#  {'source': 'As Karina says, “It is important that the award stay relevant and synced with the evolving requirements being placed on the business from a commercial, customer and co-worker perspective.',
#   'target': 'Como dice Karina, "es importante que el premio refleje la realidad y se mantenga en sintonía con la evolución de los requisitos que se imponen a la empresa desde el punto de vista comercial, de los clientes y de los/as colaboradores/as.'},
#  {'source': 'A green room with an ELVARLI shelf unit being used as dressing table with TIBAST curtains used as a door pulled to one side.',
#   'target': 'Una habitación verde con una estantería ELVARLI utilizada como tocador y unas cortinas TIBAST a modo de puerta a un lado.'},
#  {'source': 'never overestimate how', 'target': 'No debemos dar por hecho'},
#  {'source': 'for growth 3 / year',
#   'target': 'for Growth Sessions 3 veces al año'},
#  {'source': 'Which style group does TORARED belong to?',
#   'target': '¿En qué estilo se engloba TORARED?'},
#  {'source': 'What do you think has happened\xa0here?\xa0',
#   'target': '¿Qué crees que ha pasado aquí?\xa0'},
#  {'source': 'going to work, having time for family,',
#   'target': 'que va a trabajar,\u2028pasa tiempo con la familia'},
#  {'source': 'Note that this is a global training and some products vary between markets.',
#   'target': 'Ten en cuenta que se trata de una formación global y algunos productos varían en función del mercado.'},
#  {'source': 'So, when the customers are shopping,',
#   'target': 'Cuando los clientes estén comprando,'},
#  {'source': 'IKEA retailers are responsible for setting the pricing strategy/direction for their market, determining the retail price in the market and securing lowest price leadership in the market on comparable products and services.',
#   'target': 'Los minoristas de IKEA son responsables de establecer la estrategia/dirección de precios para su mercado, determinar el precio minorista en el mercado y garantizar el liderazgo de precios más bajos en el mercado de productos y servicios comparables.'},
#  {'source': 'One of the secondary display techniques. Used to present the most attractive side of the product so it faces visitors. It creates a strong product impression.',
#   'target': 'Una de las técnicas de exposición secundarias. Sirve para presentar el lado más atractivo del producto orientado hacia el visitante. Crea una sólida imagen del producto.'},
#  {'source': 'en_US', 'target': 'en_US'},
#  {'source': 'Roles & Responsibilities',
#   'target': 'Funciones y responsabilidades'},
#  {'source': 'The Customer Support Centre should verify the shopping list of discontinued articles, which was created by the customer.',
#   'target': 'El Centro de Atención al Cliente debe verificar la lista de compra de artículos descatalogados que creó el cliente.'},
#  {'source': 'Rintaro adds, “IKEA made a strong impression for a new customer segment - light gamers - that affordable and sustainable products and solutions are available at IKEA.”',
#   'target': 'Rintaro añade: "IKEA ha causado una fuerte impresión en un nuevo sector de clientes, los jugadores ocasionales, a los que ha hecho ver que en IKEA hay productos y soluciones asequibles y sostenibles".'},
#  {'source': 'This classy rug is hand-knotted by skilled craftspeople, unique in design and size.',
#   'target': 'Esta elegante alfombra está anudada a mano por expertos artesanos, única en diseño y tamaño.'},
#  {'source': 'it is poisonous or too difficult',
#   'target': 'es muy difícil conseguir'},
#  {'source': 'And why not add a clever swivel shelf to your ENHET combination to keep the finer details in check?',
#   'target': '¿Y qué tal añadir un estante giratorio a tu combinación ENHET para no perder de vista los detalles?'},
#  {'source': 'Sometimes we are a part of the problem and we have decided to be part of the solution.',
#   'target': 'A veces, somos parte del problema y hemos decidido ser parte de la solución.'},
#  {'source': 'Always secure that you have disconnected\u2028the lamp to the circuit before starting.',
#   'target': 'Desconecta la lámpara de la corriente\u2028antes de empezar a trabajar con ella.'},
#  {'source': 'It makes a room seem darker.',
#   'target': 'Hace que la estancia parezca más oscura.'},
#  {'source': 'It is a BTI price family.',
#   'target': 'Es una serie de precios increíbles (BTI).'},
#  {'source': 'Fill in this form to initiate an involutary separation of a co-worker, after discussing the separation procedure with the P&C Business Partner and your co-worker.',
#   'target': 'Completa este formulario para iniciar la baja no voluntaria de un/a colaborador/a, tras consultar el procedimiento de salida con P&C Business Partner y el/la colaborador/a.'},
#  {'source': 'My name is Mulunda Kombo,and welcome to my session.',
#   'target': 'Me llamo Mulunda Komboy os doy la bienvenida a mi sesión.'},
#  {'source': 'Like cotton and viscose.',
#   'target': 'Como el algodón y la viscosa.'},
#  {'source': 'You meet!', 'target': 'Reunión'},
#  {'source': 'When designing products for reuse, they must be easy to disassemble and reassemble, eliminating the risk of breakage when moving them within a customer’s home, between different homes and customer, store and refurbishment centers.',
#   'target': 'A la hora de diseñar productos para su reutilización, deben ser fáciles de desmontar y volver a montar a fin de eliminar el riesgo de roturas al trasladarlos dentro de la casa del cliente, de un hogar a otro, o entre diferentes tiendas o centros de restauración.'},
#  {'source': 'Solutions that demonstrate our home furnishing competence and strongly promote sales.',
#   'target': 'Soluciones que demuestran nuestra competencia y promueven vigorosamente las ventas.'},
#  {'source': "That's where the circular economy is great.",
#   'target': 'para eso la economía circular es fantástica.'},
#  {'source': 'we now know that that basic tenet',
#   'target': 'es el principio básico del capitalismo,'},
#  {'source': 'This creates commitment and action.',
#   'target': 'Esto genera compromiso y acción.'},
#  {'source': 'The width of the IKEA range is about offering different products within a given product function.',
#   'target': 'La extensión del surtido IKEA está en ofrecer diferentes productos en una función de producto determinada.'},
#  {'source': 'What makes this product easy to take home?',
#   'target': '¿Por qué es tan fácil llevar a casa este producto?'},
#  {'source': 'While our competitors adjust their prices on a frequent basis.',
#   'target': 'Sin embargo, nuestra competencia ajusta sus precios con frecuencia.'},
#  {'source': 'IKEA Basic Traditional', 'target': 'IKEA Básico Tradicional'},
#  {'source': 'week 35 and week 36,',
#   'target': 'la semana\xa035 y la semana\xa036,'},
#  {'source': 'the temperature.', 'target': 'la temperatura.'},
#  {'source': 'FENOMEN is available as one standard candle block.',
#   'target': 'FENOMEN está disponible como una vela gruesa estándar.'},
#  {'source': 'After two one-to-ones in which I listened to Marie and made some small changes, she started showing her old enthusiasm and doing quality work.',
#   'target': 'Después de dos sesiones individuales en las que Marie me contó sus inquietudes, introduje algunos pequeños cambios y Marie empezó a mostrar su entusiasmo de siempre y a hacer un trabajo de gran calidad.'},
#  {'source': 'life needs to start with work.',
#   'target': 'es con un buen trabajo.'},
#  {'source': 'Go for outdoor comfort',
#   'target': 'Disfruta de la comodidad al aire libre'},
#  {'source': 'LS:\tDo you dream of a permanent home?',
#   'target': 'LS:\t¿Soñáis con un hogar permanente?'},
#  {'source': 'Refer to the poster Training flow and show the flipchart you prepared earlier with the timetable for Day 1.',
#   'target': 'Consulta el póster Desarrollo del curso y enseña el rotafolio que preparaste antes con el horario del día 1.'},
#  {'source': 'Inform the feedback provider that they can answer the questions asked by the Line Manager on their team’s performance',
#   'target': 'Informa al proveedor de los comentarios de que puede responder a las preguntas formuladas por el responsable directo sobre el desempeño de su equipo.'},
#  {'source': "MUSKOT's simple design makes it adaptable and versatile.",
#   'target': 'El diseño simple de MUSKOT hace que sea muy versátil y se adapte a todo tipo de espacios.'},
#  {'source': 'This secures that the layout provides optimal conditions for commerciality, which means inspiration, efficiency and profitability.',
#   'target': 'Así se garantiza que el diseño brinde las condiciones óptimas para la comercialización, lo que se traduce en inspiración, eficiencia y rentabilidad.'},
#  {'source': 'The handshower five spray comes with full, mist, massage, full/mist, and full/massage spray functions.',
#   'target': 'La ducha de mano de cinco chorros viene con las funciones de espray total, rociador, masaje, total/rociador y total/masaje.'},
#  {'source': 'Did you know that nine out of ten of us, all over the world, breathe air that is harmful to our health?',
#   'target': '¿Sabías que nueve de cada diez personas de todo el mundo respiran aire perjudicial para la salud?'},
#  {'source': 'Someone constantly watching out for you or other co-workers might be planning to do something when you’re not looking',
#   'target': 'Alguien que no deja de mirarte a ti o a otros colaboradores/colaboradoras podría estar planeando hacer algo cuando no mires.'},
#  {'source': 'A bright café with white tables, black chairs, a counter area with a coffee machine and a black and white menu board.',
#   'target': 'Una cafetería luminosa con mesas blancas, sillas negras, una zona de mostrador con una cafetera y un menú en blanco y negro.'},
#  {'source': '- Wonderful.\u2028- Yes.', 'target': '- Maravilloso.\u2028- Sí.'},
#  {'source': 'Average cheque', 'target': 'Cheque medio'},
#  {'source': 'To refresh your memory: each order picker has three points of contact with the floor:  ',
#   'target': 'Refresquemos la memoria: los recogepedidos tienen tres puntos de contacto con el suelo:  '},
#  {'source': 'Rounded shape, high legs and a fixed cover that make sure the sofa always look neat and tidy.',
#   'target': 'Forma redondeada, patas altas y una funda fija que garantiza que el sofá siempre tenga un aspecto impecable.'},
#  {'source': 'What one word that describes you as a leader?',
#   'target': '¿Qué palabra te describe como líder?'},
#  {'source': 'and also to creating', 'target': 'o crear'},
#  {'source': 'Prepare the fork arms and mast',
#   'target': 'Preparar las horquillas y el mástil'},
#  {'source': '-who wakes up, cooks, eats,breathes and falls asleep here every day?',
#   'target': 'que se despierta, cocina, come, respira y duerme aquí cada día?'},
#  {'source': 'IKEA recommends any LED bulb from the IKEA range.',
#   'target': 'IKEA recomienda cualquier bombilla LED del surtido IKEA.'},
#  {'source': '– we develop ourselves for continuous growth',
#   'target': '– nos desarrollamos para crecer de forma continua'},
#  {'source': 'We make all our mirrors suitable for the bathroom because we want to give you a wide choice of styles.',
#   'target': 'Todos nuestros espejos son adecuados para el baño porque queremos ofrecerte una amplia variedad de estilos.'},
#  {'source': 'Deciding to express our sense of style and creativity.',
#   'target': 'La decisión de expresar nuestro estilo y creatividad.'},
#  {'source': "- That's it, that's it.\u2028- I'm excited about the future.",
#   'target': '- Exacto.\u2028- El futuro se presenta interesante.'},
#  {'source': 'But sometimes a photo or references to internal projects can be enough for criminals to design a successful targeted attack on IKEA.',
#   'target': 'Pero a veces una foto o referencias a proyectos internos puede ser suficiente para que los delincuentes diseñen un ataque dirigido a IKEA.'},
#  {'source': 'You can personalise your MAJORNA lighting arrangement by mixing and matching different lights from the same series.',
#   'target': 'Puedes personalizar tu solución de iluminación MAJORNA al combinar diferentes lámparas de la misma serie.'},
#  {'source': 'Sharing breaks with the same people every day can make others feel excluded.',
#   'target': 'Si siempre disfrutas de las pausas con las mismas personas, es posible que cierta gente se sienta excluida.'},
#  {'source': 'Start planning your FRÖJERED light bamboo kitchen',
#   'target': 'Comienza a planificar tu cocina FRÖJERED en bambú claro'},
#  {'source': "It's always good.", 'target': 'Siempre están buenísimas.'},
#  {'source': 'Consumer behavior is changing.',
#   'target': 'de los consumidores están cambiando.'},
#  {'source': 'These are the things that\u2028we know really inspire the many of us.',
#   'target': 'Son de las cosas\u2028que más nos inspiran a la mayoría.'},
#  {'source': 'Fits the HEMNES bed frame.',
#   'target': 'Se adapta a la estructura de cama HEMNES.'},
#  {'source': 'But then you have issueswith like classical gaming chairs.',
#   'target': 'Pero también tienes problemascon sillas de juego clásicas.'},
#  {'source': 'Yes, it´s true!', 'target': 'Sí, es verdadero.'},
#  {'source': 'A white IKEA PS cabinet with one of the doors open revealing white KUGGIS boxes, books and craft supplies.',
#   'target': 'Un armario IKEA PS blanco con una de las puertas abiertas para mostrar cajas KUGGIS blancas, libros y artículos de manualidades.'},
#  {'source': '- No!\u2028- Oh!', 'target': '- ¡No!\u2028- ¡Vaya!'},
#  {'source': "- Yeah, that's my moves.",
#   'target': '- Sí, son mis movimientos.'},
#  {'source': 'which is the most important thing',
#   'target': 'que es muy importante para'},
#  {'source': 'The input will be forwarded to the country organisation (for the country pricing) and to CBR\xa0 to improve the preconditions for leading with lowest price.',
#   'target': 'La información se enviará a la organización nacional (para conocer los precios del país) y a CBR para mejorar las condiciones previas para liderar con el precio más bajo.'},
#  {'source': 'The bed frame is the only piece of furniture in the ASKVOLL family.',
#   'target': 'La estructura de cama es el único mueble de la serie ASKVOLL.'},
#  {'source': 'For velvet, preferably remove dirt with BÄSTIS textile care roller.',
#   'target': 'En el terciopelo, quita la suciedad preferentemente con el rodillo quitapelusas BÄSTIS.'},
#  {'source': 'Anyone using saws must use the appropriate personal protective gear: ear protection, safety shoes, and safety glasses.',
#   'target': 'Quienes trabajen con sierras deben usar el equipo de protección adecuado: protección auditiva, calzado de seguridad y gafas de seguridad.'},
#  {'source': 'Use your mobile* camera to scan this QR code and enter the Now P&Cportal now!',
#   'target': 'Utiliza la cámara de tu teléfono móvil* para escanear este código QR y acceder ahora al portal Now P&C.'},
#  {'source': 'Co-worker driven feedback',
#   'target': 'Comentarios de los/as colaboradores/as'},
#  {'source': 'One of these is product tests, of which we perform over a million every year.',
#   'target': 'Entre ellos están las pruebas de productos, de las que realizamos más de un millón cada año.'},
#  {'source': 'What sustainability actions are they currently taking at work?',
#   'target': '¿Qué medidas de sostenibilidad están adoptando actualmente en el trabajo?'},
#  {'source': 'Elenas.JPG', 'target': 'Elenas.JPG'},
#  {'source': 'How does VITMOSSA feel to the touch?',
#   'target': '¿Qué tacto tiene VITMOSSA?'},
#  {'source': 'Where do you see yourself in',
#   'target': '¿Dónde situarías tu productividad'},
#  {'source': 'Close up on bedroom wooden dressing table with plastic mini chest with 2 drawers holding makeup items, and small glass vase.',
#   'target': 'Detalle de un tocador de madera en un dormitorio, con una minicómoda de plástico con dos cajones que contienen artículos de maquillaje, y un pequeño jarrón de vidrio.'},
#  {'source': 'And also since I passed 50...',
#   'target': 'Y ya que he cumplido los 50...'},
#  {'source': 'Through the insights of how behaving according to the values is good for people and business, the motivation to live the IKEA values at work will improve.',
#   'target': 'Al mejorar la comprensión sobre los beneficios que los comportamientos conformes con los valores reportan a las personas y el negocio, aumenta la motivación para aplicar los valores de IKEA en el trabajo.'},
#  {'source': 'Check in with your colleagues and friends.',
#   'target': 'Preocuparte por tus compañeros/as y amigos.'},
#  {'source': 'London 183, 245', 'target': 'Londres 183, 245'},
#  {'source': 'I have another one here for you,',
#   'target': 'Tengo otra pregunta para ti,'},
#  {'source': 'A range of traditional style furniture for newborns and beyond.',
#   'target': 'Una serie de estilo tradicional perfecta para recién nacidos y niños más mayores.'},
#  {'source': "up and it's coordinated.", 'target': 'y todo está coordinado.'},
#  {'source': 'For over a decade Ingka Group has been investing in renewable energy, which plays an important role during the current global energy crisis.',
#   'target': 'Durante más de una década, el Grupo Ingka ha invertido en energías renovables, que desempeñan un papel importante durante la actual crisis energética global.'},
#  {'source': 'Check your answers', 'target': 'Comprueba tus respuestas.'},
#  {'source': 'The following training has been cancelled:',
#   'target': 'La sesión de formación que figura a continuación se ha cancelado:'},
#  {'source': 'Teams2.jpg', 'target': 'Teams2.jpg'},
#  {'source': 'Small changes, made at scale, create big impacts.',
#   'target': 'Los pequeños cambios, realizados a gran escala, tienen un impacto enorme.'},
#  {'source': 'Because Jean-Charles, whose journey took him from working as a trader in London, to skating intensely in South Africa and Barcelona, is also a trendsetter, happy to work in the shadows while doing consulting work for some of the most influential companies today.',
#   'target': 'Y es que Jean-Charles, cuya trayectoria le llevó de trabajar como agente de bolsa en Londres a hacer skate en Sudáfrica y Barcelona sin descanso, es también un creador de tendencias, feliz de trabajar en la sombra mientras realiza labores de consultoría para algunas de las empresas más influyentes hoy en día.'},
#  {'source': 'A: The decision is very recent, and we are looking into the impact on our\xa0business.',
#   'target': 'R: La decisión es muy reciente y estamos estudiando el impacto en nuestro negocio.'},
#  {'source': 'Thank you for sharing how your company works with sustainability!',
#   'target': 'Gracias por compartir cómo trabaja tu empresa en materia de sostenibilidad.'},
#  {'source': 'Upgrade to IKEA Business Network and get even more',
#   'target': 'Pásate a la Red IKEA para Empresas y disfruta de más ventajas'},
#  {'source': 'and the girls have sent me enough.',
#   'target': 'las chicas me los han enviado.'},
#  {'source': 'High style by IKEA lovers',
#   'target': 'Alta costura creada por amantes de IKEA'},
#  {'source': 'A nifty chest of drawers for a minimalistic bedroom',
#   'target': 'Una práctica cómoda para un dormitorio minimalista'},
#  {'source': "There are plenty of great options for younger children in the Children's IKEA range.",
#   'target': 'El surtido infantil de IKEA cuenta con muchas opciones estupendas para niños más pequeños.'},
#  {'source': 'our sustainability agenda.',
#   'target': 'nuestros objetivos de sostenibilidad.'},
#  {'source': 'As a hiring manager, you have a big impact\u2028on this candidate experience.',
#   'target': 'Como Hiring Manager, influyes mucho\u2028en la experiencia del candidato.'},
#  {'source': 'IKEA Food & Beverage co-workers need to understand the importance of managing portion control and respecting holding times as a way to offer customers consistently good food.',
#   'target': 'Los trabajadores del departamento de alimentación y bebidas de IKEA deben comprender la importancia de ejercer un buen control de las raciones y de respetar los tiempos de conservación para poder ofrecer siempre buenos alimentos a los clientes.'},
#  {'source': 'performance, competence and',
#   'target': 'el rendimiento, las competencias y'},
#  {'source': 'Make sure no one is following you when you walk to the cash office.',
#   'target': 'Asegúrate de que nadie te sigue cuando entres en la sección de caja central.'},
#  {'source': 'All of the above', 'target': 'Todo lo anterior.'},
#  {'source': 'This week, I had a chat with Susanne Pulverer, Global Risk and Compliance manager, and Oszkar Solti, Fulfilment Operations Developer in IKEA Switzerland, to talk about the importance of putting safety and health first when we reopen stores.',
#   'target': 'Esta semana estuve hablando con Susanne Pulverer, responsable de Global Risk and Compliance, y Oszkar Solti, Fulfilment Operations Developer en IKEA Suiza, y charlamos sobre la importancia de poner la salud y la seguridad en primer lugar al reabrir nuestras tiendas.'},
#  {'source': 'The cotton padding.', 'target': 'El relleno de algodón.'},
#  {'source': 'Dining area with a rectangular desk, multiple, beige office chairs, a storage unit on castors, and two potted plants.',
#   'target': 'Zona de comedor con un escritorio rectangular, varias sillas de oficina beige, un módulo de almacenaje con ruedas y dos plantas en macetas.'},
#  {'source': '“When there’s no choice of buying new, you always try to look at what you have, taking care of it, and reusing it.',
#   'target': '"Cuando no hay opción de comprar algo nuevo, siempre intentas aprovechar lo que tienes, cuidarlo y reutilizarlo.'},
#  {'source': 'My partner and I like different types of coffee.',
#   'target': 'A mi pareja y a mí nos gustan distintos tipos de café.'},
#  {'source': 'What could be an evidence?',
#   'target': '¿Qué podría ser una prueba?'},
#  {'source': 'More than 2 billion people visit IKEA stores each year, across the world.',
#   'target': 'Recibimos más de 2.000 millones de visitantes al año en las tiendas IKEA de todo el mundo.'},
#  {'source': 'LÅDDAN was designed by J Fager/M Vinka.',
#   'target': 'El diseño de LÅDDAN es obra de J. Fager y M. Vinka.'},
#  {'source': 'Small living room storage for a clutter-free space',
#   'target': 'Almacenaje en un salón pequeño para mantenerlo todo recogido'},
#  {'source': 'We always try to do new things, from decoration seminars to Easter egg hunts, live cookery exhibitions, surprise raffles and so on, says Paula Corell, local marketing specialist.',
#   'target': 'Siempre tratamos de hacer cosas nuevas, desde seminarios de decoración hasta cacerías de huevos de Pascua, exhibiciones de cocina en directo, sorteos sorpresa, etc.", comenta Paula Corell, Local Marketing Specialist.'},
#  {'source': 'The IKEA LED bulb B22 400 lumen.',
#   'target': 'La bombilla LED IKEA B22 de 400 lúmenes.'},
#  {'source': 'Dine in style', 'target': 'Cena con estilo'},
#  {'source': 'The ability to easily add different backings.',
#   'target': 'La posibilidad de añadir fácilmente diferentes tipos de base.'},
#  {'source': 'Woman on light grey two seat sofa with textile cover, white rug with black and grey speckles, white throw and curtains.',
#   'target': 'Mujer en un sofá de dos plazas gris claro con funda de tela, alfombra blanca con motas negras y grises, y manta y cortinas blancas.'},
#  {'source': 'Aluminium is an efficient heat conductor, lightweight and rust resistant.',
#   'target': 'El aluminio es un conductor térmico eficiente, ligero y resistente al óxido.'},
#  {'source': 'In your journal, record ways to strengthen the communication channels in the work environment.',
#   'target': 'Anota en el diario las formas de reforzar los canales de comunicación en el entorno de trabajo.'},
#  {'source': 'Food container series',
#   'target': 'Serie de recipientes para alimentos'},
#  {'source': 'Choosing a subdomain', 'target': 'Elección de un subdominio'},
#  {'source': 'Bed spread', 'target': 'Colcha'},
#  {'source': 'What a year!', 'target': '¡Menudo año!'},
#  {'source': 'From three hours to five minutes.',
#   'target': 'De tres horas a cinco minutos.'},
#  {'source': 'many times people are like wow!',
#   'target': 'muchas veces se quedan sorprendidas.'},
#  {'source': 'Did you know that we will soon reach our goal of an equal number of men and women in all positions?',
#   'target': '¿Sabías que muy pronto alcanzaremos nuestro objetivo de igualdad entre hombres y mujeres en todos los puestos?'},
#  {'source': 'With Stockholm’s population expected to grow considerably by the year 2025, we are on an exciting expansion, creating more customer meeting points to bring our offering closer to Stockholmers, where they live, work and socialise.',
#   'target': 'Se espera que la población de Estocolmo crezca considerablemente para el año 2025. Por lo tanto, queremos expandirnos, crear puntos de encuentro con los clientes y acercar nuestra oferta a los habitantes de la ciudad, al lugar donde viven, trabajan y socializan.'},
#  {'source': "It's a promise.", 'target': 'Es una promesa.'},
#  {'source': 'Well, most people\u2028who work here are born here',
#   'target': 'La mayoría de los trabajadores\u2028que tenemos son de aquí.'},
#  {'source': 'See all clothes stands & shoe racks',
#   'target': 'Ver más percheros y zapateros'},
#  {'source': 'A light wood FRÖSET chair on a beige rug.',
#   'target': 'Sillón FRÖSET de madera clara sobre una alfombra beige.'},
#  {'source': 'and then feel grumpy and unappreciated?',
#   'target': 'y has sentido que no se ha valorado?'},
#  {'source': 'at the best prices', 'target': 'al mejor precio'},
#  {'source': 'The doors have soft-closing hinges which make them close softly and quietly.',
#   'target': 'Las puertas tienen bisagras de cierre suave que las cierran de forma fácil y silenciosa.'},
#  {'source': 'Improving so that they have\u2028a seamless shopping experience.',
#   'target': 'Mejorar para que el cliente tenga\u2028una experiencia de compra perfecta.'},
#  {'source': 'Over three years, the campaigns have raised nearly EUR 30.8 million to provide light and renewable energy sources for refugee families.',
#   'target': 'Durante 3 años, las campañas han recaudado cerca de 30,8 millones de euros para suministrar electricidad y fuentes de energía renovable a familias en situación de refugio.'},
#  {'source': 'FJÄLLA is made up of boxes and organisers.',
#   'target': 'FJÄLLA se compone de cajas y organizadores.'},
#  {'source': '“In Europe, we have many stores and the distances are not so great so we have been able to collaborate strongly on this,” Johan says.',
#   'target': '"En Europa hay muchas tiendas y las distancias que las separan no son tan grandes, por lo que la colaboración ha sido muy estrecha", recalca Johan.'},
#  {'source': 'Several times the word "manmade" is used.',
#   'target': 'Se utiliza la palabra "artificial" varias veces.'},
#  {'source': 'The image below shows some common sources of residential indoor air pollution.',
#   'target': 'La siguiente imagen muestra algunas fuentes comunes de contaminación del aire en los hogares.'},
#  {'source': 'The planet is protected', 'target': 'Se protege el planeta'},
#  {'source': 'It’s mandatory that at least 6% of the entire gross area in IKEA customer meeting points is devoted to IKEA food solutions.',
#   'target': 'Es obligatorio que al menos el 6% de la superficie comercial de los puntos de contacto con el cliente de IKEA esté dedicada a soluciones de IKEA Food.'},
#  {'source': 'All parts of the IKEA Concept framework provide a solid base for how to execute our business idea.',
#   'target': 'Todas las partes del marco del concepto IKEA ofrecen una base sólida para ejecutar nuestra idea de negocio.'},
#  {'source': 'It is not a smart space saver.',
#   'target': 'No es una forma inteligente de ahorrar espacio.'},
#  {'source': 'How can I request a Mentor in an Unsupervised program?',
#   'target': '¿Cómo puedo solicitar un orientador en un programa sin supervisión?'},
# ...
#   'target': 'Y siguiendo con el espectro veraniego, también está STÖRTSKÖN, una explosión de frambuesas frescas, hojas de verdura y violetas.'},
#  {'source': 'http://www.aboutcookies.org',
#   'target': 'http://www.aboutcookies.org/'},
#  {'source': 'Do: Ask participants to consider the following question: “What if there were no manager?” ',
#   'target': 'Haz lo siguiente: Pide a los/as participantes que reflexionen sobre la siguiente pregunta: “¿Y si no hubiera un mando?”.'},
#  {'source': "It's the sheer size of",
#   'target': 'Como digo, es la enorme cantidad'},
#  {'source': 'One Solution:', 'target': 'One Solution:'},
#  {'source': 'Duvets ', 'target': 'Edredones'},
#  {'source': 'About a decade ago, she attended a theater academy, went to a circus show, and became crazy about aerial dance as a sport.',
#   'target': 'Hace una década, la academia de teatro a la que asistía y los circos que visitaba despertaron en ella la pasión por la danza aérea como deporte.'},
#  {'source': 'Consider the needs, dreams and',
#   'target': 'Piensa en las necesidades, sueños y'},
#  {'source': 'will understand the importance\u2028of giving back',
#   'target': 'entiendan la importancia\u2028de ser un apoyo'},
#  {'source': 'We do not allow our own beliefs and values to be politicised by extreme groups or movements.\xa0',
#   'target': 'No permitimos que nuestros valores y creencias sean politizados por grupos o movimientos extremos.\xa0'},
#  {'source': 'That means you can relax and stay seated for another helping (or two) of your favourite dish at the table.',
#   'target': 'Eso significa que puedes relajarte y quedarte sentado a la mesa para otra ración (o dos) de tu plato favorito.'},
#  {'source': 'They fold flat to save space and can be stored away easily.',
#   'target': 'Se pliegan para ahorrar espacio y se pueden guardar fácilmente.'},
#  {'source': 'which is as much as the total transport sector.',
#   'target': 'a nivel mundial, lo mismo que todo el sector del transporte.'},
#  {'source': 'Monica Mulder designed the swivel chair',
#   'target': 'Monica Mulder diseñó esta silla giratoria'},
#  {'source': 'The experience', 'target': 'La experiencia'},
#  {'source': 'for at least two to three minutes,or at least until you get to the',
#   'target': 'durante dos o tres minutos,o hasta que tenga la'},
#  {'source': 'How can you learn from the knowledge and insights that the co-worker brings?',
#   'target': '¿Cómo puedes aprender de los conocimientos y la perspectiva que aporta el/la colaborador/a?'},
#  {'source': 'code, code of conduct, risk, risks, mandatory, business integrity, human rights, working envrionment, assets, confidential information',
#   'target': 'código, código de conducta, riesgo, riesgos, obligatorio, integridad empresarial, derechos humanos, entorno laboral, activos, información confidencial'},
#  {'source': 'This has always been the driving force',
#   'target': 'Este ha sido el motor que nos ha'},
#  {'source': 'now comes from these new business',
#   'target': 'ahora proceden de estos nuevos modelos'},
#  {'source': 'And it won’t go to waste.',
#   'target': 'Y no se van a desaprovechar.'},
#  {'source': 'Minutes from the safety meetings shall be sent to the Ingka Group Construction Project Manager.',
#   'target': 'Las minutas de las reuniones de seguridad se enviarán al Construction Project Manager del Grupo Ingka.'},
#  {'source': 'Offering add-on sales to complete the offer.',
#   'target': 'Ofrecer productos adicionales para completar la oferta.'},
#  {'source': 'The formal governance model (grey boxes) shows the governance when the programme is handed over to the business.',
#   'target': 'El modelo de control formal (recuadros grises) muestra el mecanismo de control del programa de SCS una vez que la entidad jurídica se ha hecho responsable de éste.'},
#  {'source': 'Only works with cabinets (not open frames).',
#   'target': 'Solo se puede usar con armarios (no con estructuras abiertas).'},
#  {'source': '61% of the wood we used in FY16 came from more sustainable sources1.',
#   'target': 'Nuestro objetivo para agosto de 2020 es que el 100 % de la madera, papel y cartón que utilizamos proceda de fuentes más sostenibles.'},
#  {'source': 'birds and insects and mammals,',
#   'target': 'aves, insectos, mamíferos,'},
#  {'source': '“Failure is an opportunity to grow.”',
#   'target': '“El fracaso es una oportunidad para crecer”.'},
#  {'source': 'BETTER LIVES FOR THE MANY –',
#   'target': 'MEJOR CALIDAD DE VIDA PARA LA MAYORÍA'},
#  {'source': 'How do you keep the rug looking fresh?',
#   'target': '¿Qué hay que hacer para mantener la alfombra limpia?'},
#  {'source': 'Front week', 'target': 'Semana de demostración'},
#  {'source': 'Hinged or sliding.', 'target': 'Con bisagras o correderas.'},
#  {'source': 'A mix of neutral-toned textiles for a coordinated look',
#   'target': 'Una combinación de textiles en tonos neutros para lograr un estilo conjuntado'},
#  {'source': 'Fork arms are always trailing',
#   'target': 'Las horquillas van siempre detrás'},
#  {'source': 'It tells the story of the life of the animal.',
#   'target': 'Cuenta la historia de la vida del animal.'},
#  {'source': 'BOARD DEPUTY MEMBERS', 'target': 'MIEMBROS ADJUNTOS DE LA JUNTA'},
#  {'source': 'Comfort for you and less foam for the environment.',
#   'target': 'Comodidad para todo aquel que se siente en el sofá y menos espuma para el medio ambiente.'},
#  {'source': 'Use alone or mix and match with other items in the GLADELIG series to coordinate your table setting on both weekdays and weekends.',
#   'target': 'Utilízalos por sí solos o combínalos con otros artículos de la serie GLADELIG para conjuntar la presentación de la mesa tanto entre semana como los fines de semana.'},
#  {'source': 'A black KRAGSTA nest of two tables is slightly separated, with the larger table holding a glass vase of flowers by a sofa.',
#   'target': 'Un nido KRAGSTA negro de dos mesas está ligeramente separado, y la mesa más grande sostiene un jarrón de flores con un sofá.'},
#  {'source': 'This impacts how we feel at work and at the same time how we perform” says Liliana Plewińska, Payroll Specialist at global level.',
#   'target': 'Esto influye en cómo nos sentimos en el trabajo y, por lo tanto, en nuestro rendimiento", comenta Liliana Plewińska, Payroll Specialist a nivel mundial.'},
#  {'source': 'It can be mounted inside or outside the window frame, or in the ceiling.',
#   'target': 'Se puede instalar por dentro o por fuera del marco de la ventana, o acoplar al techo.'},
#  {'source': "My former social assistant told me about IKEA Mons's Skills for Employment program.”\xa0\xa0",
#   'target': 'mi antiguo asistente social me habló del programa Skills for Employment de IKEA Mons.\xa0\xa0'},
#  {'source': 'From impersonal and predictable',
#   'target': 'De una casa impersonal y predecible'},
#  {'source': 'Ability to build trustful and strong relationships while demonstrating a service minded approach towards colleagues and partners',
#   'target': 'Capacidad para construir relaciones sólidas y de confianza, demostrando al mismo tiempo un espíritu de servicio orientado a los/as compañeros/as y socios'},
#  {'source': 'With your team and peers',
#   'target': 'Con tu equipo y compañeros/as'},
#  {'source': 'Just make sure to blow out the candle.',
#   'target': 'Solo tienes que asegurarte de apagar la vela.'},
#  {'source': '0.1% of annual GDP is generated thanks to IKEA.1',
#   'target': 'Un 0,1% del PIB anual se genera  gracias a IKEA.1'},
#  {'source': 'We don’t put values first often enough',
#   'target': 'No damos prioridad a los valores con la suficiente frecuencia'},
#  {'source': 'They have high service expectations',
#   'target': 'Tienen grandes expectativas de servicio'},
#  {'source': 'All the textiles nearest to your skin are made of 100% cotton from sustainable sources.',
#   'target': 'Todos los tejidos que quedan más cerca de la piel están hechos de algodón 100\xa0%, obtenido de forma sostenible.'},
#  {'source': 'but also siding with\u2028the many people',
#   'target': 'a la mayoría de las personas\u2028a superar esta etapa de enorme inflación.'},
#  {'source': "So I think it's pretty cool\u2028to be here in every sense.",
#   'target': 'Estar aquí es\u2028genial en todos los sentidos.'},
#  {'source': 'Durable and long lasting materials throughout the complete family.',
#   'target': 'Materiales resistentes y duraderos en toda la serie.'},
#  {'source': 'All that’s left is to sit and serve!',
#   'target': '¡Pues todos a la mesa!'},
#  {'source': 'Together, we can reach our goal',
#   'target': 'Unidos, alcanzaremos nuestra meta'},
#  {'source': 'want to leave Ukraine\u2028but wants to stay safe,',
#   'target': 'que no quiere abandonar Ucrania,\u2028pero sí estar a salvo.'},
#  {'source': 'LORD', 'target': 'SEÑOR'},
#  {'source': '100% recycled PET bottles.',
#   'target': 'Botellas PET 100\xa0% recicladas.'},
#  {'source': 'The word impossible doesn’t exist in the IKEA language.',
#   'target': 'La palabra "imposible" no existe en el vocabulario IKEA.'},
#  {'source': "Oh my God, you're literally\u2028giving me goosebumps",
#   'target': 'Vaya, se me eriza la piel literalmente'},
#  {'source': 'Our multichannel journey focuses on four central aspects of our business: our stores, e-commerce, logistics and service.',
#   'target': 'El proceso de transformación multicanal se centra en cuatro aspectos centrales del negocio: nuestras tiendas, comercio electrónico, logística y servicio.'},
#  {'source': 'I do not succeed in any of my applications',
#   'target': 'No tengo éxito en ninguna de mis solicitudes'},
#  {'source': 'To meet the highest quality / safety standards and use materials / production methods that require the minimum amount of chemicals.',
#   'target': 'Para garantizar que cumplen con los más altos requisitos de calidad/seguridad, y que utilizan materiales/métodos de producción que requieren de una mínima cantidad de productos químicos.'},
#  {'source': 'Reach truck - forklift operator training',
#   'target': 'Carretilla retráctil – Curso de maquinista de carretilla elevadora'},
#  {'source': 'at home that will nourish bees in four ways.',
#   'target': 'en casa para alimentar a las abejas.'},
#  {'source': 'Mapped Competency', 'target': 'Competencia asignada'},
#  {'source': 'Lead the country RCMP PS&I team.',
#   'target': 'Dirigir el equipo de PS&I del RCMP del país.'},
#  {'source': 'Actually,our range covers all this.',
#   'target': 'De hecho,sí que disponemos de ellos.'},
#  {'source': 'During your onboarding, write down any difficult experiences, challenges and mistakes.',
#   'target': 'Durante el proceso de incorporación, escribe cualquier experiencia difícil, desafío o error que hayas experimentado.'},
#  {'source': 'In-store resources like shopping tools, planning tools, brochures and catalogues.',
#   'target': 'Recursos en la tienda, como herramientas de compra, herramientas de planificación, folletos y catálogos.'},
#  {'source': 'Click on the question marks to learn more about the features of our brackets and hooks.',
#   'target': 'Haz clic en los signos de interrogación para obtener más información sobre las características de los soportes y los ganchos.'},
#  {'source': 'Many of the products have several different functions.',
#   'target': 'Muchos de los productos tienen varias funciones diferentes.'},
#  {'source': 'Put it on one side or both,depending on your spice tolerance.',
#   'target': 'Podéis echarla en uno o ambos lados,depende de cómo os sienten las especias.'},
#  {'source': 'Please note that the form would be signed by your line manager first.',
#   'target': 'Ten en cuenta que el formulario debe ser firmado primero por tu manager directo.'},
#  {'source': 'Please note: within the facilitation notes contained within the PowerPoint for each topic, you will find optional icebreaker activities which require additional materials, and these will require more time (approx.',
#   'target': 'Nota: En las notas para la presentación que se incluyen en el PowerPoint de cada tema, encontrarás actividades opcionales para romper el hielo que requieren materiales adicionales y que requerirán más tiempo (aproximadamente'},
#  {'source': 'while some other might just have\u2028heard the name SPACE10 float around.',
#   'target': 'y puede que a otros solo\u2028os suene el nombre SPACE10.'},
#  {'source': 'Report any deviations to your manager.',
#   'target': 'Comunica cualquier diferencia a tu mando.'},
#  {'source': 'Here in Manchester, we understand\u2028the importance of Keeping our shelves full',
#   'target': 'Aquí en Manchester, entendemos la\u2028importancia de tener los estantes llenos'},
#  {'source': 'Go to Help centre and click on Show in 3D.',
#   'target': 'Id a la Ayuda y haced clic en Mostrar en 3D.'},
#  {'source': 'While the kitchens used for filming weren’t functioning, TILLREDA models with preheated pans conveyed the heat and sensation of preparing food - making it possible for the #CocinaConIKEA concept to be adopted in any store.',
#   'target': 'Aunque las cocinas utilizadas para el rodaje no estaban en funcionamiento, los modelos TILLREDA con sartenes precalentadas transmitían el calor y la sensación de estar preparando la comida, lo que permitía adoptar el concepto #CocinaConIKEA en cualquier tienda.'},
#  {'source': 'Low and high-back version available allows for different seating positions and arrangements.',
#   'target': 'Disponibles dos versiones, una con respaldo alto y otra con respaldo bajo, para permitir diferentes posiciones y combinaciones.'},
#  {'source': 'EFTERSMAK Forced Air Oven',
#   'target': 'Horno de aire forzado EFTERSMAK'},
#  {'source': 'KLIPPAN is a high price product.',
#   'target': 'KLIPPAN se encuentra en el rango de precios altos.'},
#  {'source': 'In Conference Functionality',
#   'target': 'Funcionalidad de conferencia'},
#  {'source': 'Approximately 600,000 radiate pine seedlings will be planted over a five-year period covering 3k ha, which is the equivalent of over 4,000 football pitches.',
#   'target': 'Se plantarán unas 600 000 plantas de semillero de pino insigne durante un período de cinco años, que abarcarán 3000 hectáreas; es decir, algo equiparable a más de 4000 campos de fútbol.'},
#  {'source': 'That performance can be adjusted in the Talent Review',
#   'target': 'El desempeño se puede ajustar en el Análisis de Talento'},
#  {'source': 'It’s the best way to avoid damage.',
#   'target': 'Es la mejor manera de evitar daños.'},
#  {'source': 'Size: 50 cm x \xa050 cm.', 'target': 'Tamaño: 50x50\xa0cm.'},
#  {'source': 'In this hands-on workshop, you get the opportunity to apply your new ideas and know-how.',
#   'target': 'En este taller práctico, tendrás la oportunidad de aplicar las nuevas ideas y técnicas que has aprendido.'},
#  {'source': "That's why we haverange allocation guidelines.",
#   'target': 'Por eso contamos con directricespara la asignación del surtido.'},
#  {'source': 'At Ingka Group, we want to create a work environment where everyone feels that they can speak up.',
#   'target': 'En el Grupo Ingka, queremos crear un ambiente de trabajo en el que todos sientan que pueden hablar.'},
#  {'source': 'Winter weather',
#   'target': 'Condiciones meteorológicas invernales'},
#  {'source': "So do I, I'm desperate for it\u2028but let's see how they go.",
#   'target': '¡Toma, y yo! Me encantaría.\u2028Pero veremos cuál de las dos gana.'},
#  {'source': 'As with any battery, the ability to retain charging power will gradually reduce over time.',
#   'target': 'Como con cualquier batería, la capacidad de conservación de la energía de carga se reducirá gradualmente con el tiempo.'},
#  {'source': 'All you have to do is crumble them',
#   'target': 'lo que tienes que hacer es desmenuzarlos'},
#  {'source': 'Country Digital Team and system Super Users\u2028What:',
#   'target': 'Country Digital Team y Super Users del sistema\u2028Qué:'},
#  {'source': 'For example a 60 x 55 x 40 cm frame on top of a 80 x 55 x 180 cm frame?',
#   'target': 'Por ejemplo, una estructura de 60 x 55 x 40 cm sobre otra estructura de 80 x 55 x 180 cm.'},
#  ...]

# %%
time = str(datetime.now())

batch_size=16
learning_rate=2e-5 
weight_decay=0.01
save_limit=10
epochs=20

# n.b. need to add early stopping with longer training times
args = Seq2SeqTrainingArguments(
    f"../../models/Checkpoints/IKEA_MT_en_GB-es_ES_{time}",
    evaluation_strategy = "epoch",
    learning_rate = learning_rate,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay = weight_decay,
    save_total_limit = save_limit,
    num_train_epochs = epochs,
    predict_with_generate=True    
)


trainer = Seq2SeqTrainer(
    trained_model,
    args,
    train_dataset = tokenized_dataset["train"],
    eval_dataset = tokenized_dataset["validation"],
    data_collator = data_collator,
    tokenizer = tokenizer,
    compute_metrics = compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation. If translation are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# /home/jupyter/.virtualenvs/ikea-mt/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 210502
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 263140
#     <div>
#
#       <progress value='238348' max='263140' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [238348/263140 12:06:53 < 1:15:36, 5.46 it/s, Epoch 18.12/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.946400</td>
#       <td>0.851741</td>
#       <td>50.672347</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.828700</td>
#       <td>0.824130</td>
#       <td>52.075698</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.731500</td>
#       <td>0.821140</td>
#       <td>52.460513</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.683100</td>
#       <td>0.821804</td>
#       <td>52.666289</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.620100</td>
#       <td>0.824958</td>
#       <td>53.431321</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.565000</td>
#       <td>0.828585</td>
#       <td>53.987921</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.533900</td>
#       <td>0.842678</td>
#       <td>54.200737</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.491400</td>
#       <td>0.849684</td>
#       <td>54.473092</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.469100</td>
#       <td>0.864588</td>
#       <td>54.468591</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.446000</td>
#       <td>0.874038</td>
#       <td>54.932497</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.411900</td>
#       <td>0.882640</td>
#       <td>54.718833</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.389400</td>
#       <td>0.889340</td>
#       <td>54.712102</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.363800</td>
#       <td>0.900787</td>
#       <td>54.819987</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.352500</td>
#       <td>0.911793</td>
#       <td>55.012925</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.335900</td>
#       <td>0.920263</td>
#       <td>54.899873</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.308700</td>
#       <td>0.929369</td>
#       <td>55.294977</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.301900</td>
#       <td>0.933689</td>
#       <td>55.124979</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.295300</td>
#       <td>0.942285</td>
#       <td>55.253979</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-10500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-11500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-12500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation. If translation are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2148
#   Batch size = 16
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-13500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-14500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-222000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-227500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-222500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-223000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-228500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-223500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-224000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-229500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-224500] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# The following columns in the evaluation set don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation. If translation are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2148
#   Batch size = 16
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-232000] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237500
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237500/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237500/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237500/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-237500/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-232500] due to args.save_total_limit
# Saving model checkpoint to ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-238000
# Configuration saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-238000/config.json
# Model weights saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-238000/pytorch_model.bin
# tokenizer config file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-238000/tokenizer_config.json
# Special tokens file saved in ../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-238000/special_tokens_map.json
# Deleting older checkpoint [../../models/Checkpoints/IKEA_MT_en_GB-es_ES_2023-01-11 07:51:23.419419/checkpoint-233000] due to args.save_total_limit

# %%
trainer.save_model('../../models/en_GB-es_ES/IKEA_MT-en_GB-es_ES_' + time)
# Out:
# Saving model checkpoint to ../../models/en_GB-es_ES/IKEA_MT-en_GB-es_ES_2023-01-11 07:51:23.419419
# Configuration saved in ../../models/en_GB-es_ES/IKEA_MT-en_GB-es_ES_2023-01-11 07:51:23.419419/config.json
# Model weights saved in ../../models/en_GB-es_ES/IKEA_MT-en_GB-es_ES_2023-01-11 07:51:23.419419/pytorch_model.bin
# tokenizer config file saved in ../../models/en_GB-es_ES/IKEA_MT-en_GB-es_ES_2023-01-11 07:51:23.419419/tokenizer_config.json
# Special tokens file saved in ../../models/en_GB-es_ES/IKEA_MT-en_GB-es_ES_2023-01-11 07:51:23.419419/special_tokens_map.json

# %%
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation. If translation are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2148
#   Batch size = 16
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 01:44]
#     </div>
# {'eval_loss': 0.9461814761161804,
#  'eval_bleu': 55.268718,
#  'eval_runtime': 123.5558,
#  'eval_samples_per_second': 17.385,
#  'eval_steps_per_second': 1.093,
#  'epoch': 20.0}
