# %%
import os
import torch
import random
import datasets

import numpy as np
import pandas as pd

from tqdm.auto import tqdm
from datetime import datetime
from transformers import AdamW
from transformers import get_scheduler
from torch.utils.data import DataLoader
from IPython.display import display, HTML
from datasets import Dataset, DatasetDict, load_dataset, load_metric
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
def process_data():
    """
    Output: Translated text of the source text
    :param src_text: source string
    """ 
    
    #Load data (needs to be changed to loading from BQ or bucket)
    df = pd.read_csv('../../data/en_GB-da_DK/en_GB-da_DK_batch_0.csv', engine='python')

    df = df[['source', 'target']] # will be redundent when setup 
    df['source'] = df['source'].apply(lambda s: str(s))
    df['target'] = df['target'].apply(lambda s: str(s))

    # Transform to HuggingFace Dataset
    data = Dataset.from_pandas(pd.DataFrame({'translation': df.to_dict('records')})) 

    # Split data into training sets
    train_test_valid = data.train_test_split(shuffle=True, seed=7, test_size=0.02)
    test_valid = train_test_valid['test'].train_test_split(shuffle=True, seed=7, test_size=0.5)

    # Convert to train/validate/test
    dataset = DatasetDict({
        'train': train_test_valid['train'],
        'validation': test_valid['test'],
        'test': test_valid['train']})
     
    return dataset

# %%
def tokenization_processing(dataset, source_len=128, target_len=128,
                            source="source", target="target"):
    """
    Output: Generates tokenized data using the attributes of the base model
    :param dataset: raw dataset to transform
    :param source_len: maximum sentence length for source string
    :param target_len: maximum sentence length for target string
    :param source: source language
    :param target: target language
    """
    
    inputs = [s[source] for s in dataset["translation"]]
    targets = [s[target] for s in dataset["translation"]]
    
    model_inputs = tokenizer(inputs, max_length=source_len, truncation=True)
    
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(targets, max_length=target_len, truncation=True)
        
    model_inputs["labels"] = labels["input_ids"]
    
    return model_inputs

# %%
def compute_metrics(predictions): # n.b. can add more metrics later
    """
    Output: evaluation metrics to track model performance in training
    :param predictions: output of predictions to decode
    """
    
    metric = load_metric("sacrebleu")
    
    def process_text(predictions, labels):
        preds = [pred.strip() for pred in predictions]
        labels = [[label.strip()] for label in labels]
        return preds, labels
    
    preds, labels = predictions
    
    if isinstance(preds, tuple):
        preds = preds[0]
    
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds, decoded_labels = process_text(decoded_preds, decoded_labels)
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels)
    result = {"bleu": result["score"]}
    
    result = {k: round(v, 6) for k, v in result.items()} #round results
    
    return result

# %%
model_name="Helsinki-NLP/opus-mt-en-da"

dataset = process_data()

print('load models and data collator')
trained_model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

data_collator = DataCollatorForSeq2Seq(tokenizer, model=trained_model)
# Out:
# load models and data collator

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 155967
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 1592
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 1592
#     })
# })

# %%
tokenized_dataset = dataset.map(tokenization_processing, batched=True)
# Out:
#   0%|          | 0/156 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
time = str(datetime.now())

batch_size=16
learning_rate=2e-5 
weight_decay=0.01
save_limit=10
epochs=20

# n.b. need to add early stopping with longer training times
args = Seq2SeqTrainingArguments(
    f"../../models/checkpoints/IKEA_MT_en_GB-da_DK_{time}",
    evaluation_strategy = "epoch",
    learning_rate = learning_rate,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    weight_decay = weight_decay,
    save_total_limit = save_limit,
    num_train_epochs = epochs,
    predict_with_generate=True    
)


trainer = Seq2SeqTrainer(
    trained_model,
    args,
    train_dataset = tokenized_dataset["train"],
    eval_dataset = tokenized_dataset["validation"],
    data_collator = data_collator,
    tokenizer = tokenizer,
    compute_metrics = compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `MarianMTModel.forward` and have been ignored: translation. If translation are not expected by `MarianMTModel.forward`,  you can safely ignore this message.
# /home/jupyter/.virtualenvs/ikea-mt/lib/python3.7/site-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 155967
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 194960
#     <div>
#
#       <progress value='83185' max='194960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 83185/194960 4:30:56 < 6:04:03, 5.12 it/s, Epoch 8.53/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.877100</td>
#       <td>0.807595</td>
#       <td>52.817803</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.749100</td>
#       <td>0.766236</td>
#       <td>54.134318</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.659300</td>
#       <td>0.750477</td>
#       <td>54.496762</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.588500</td>
#       <td>0.746495</td>
#       <td>55.125120</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.532900</td>
#       <td>0.748914</td>
#       <td>55.496022</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.480100</td>
#       <td>0.750624</td>
#       <td>55.953125</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.453200</td>
#       <td>0.752074</td>
#       <td>56.264667</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.419600</td>
#       <td>0.760601</td>
#       <td>56.315842</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-500/special_tokens_map.json
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-3500/special_tokens_map.json
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-11500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-11500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-11500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-12500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-13500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-14000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-14000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-14000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-9000] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-21500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-22500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-23500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-18500] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-31500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-31500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-31500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-31500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-31500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-26500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-27000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-32500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-27500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-28000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-33500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-28500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-34000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-34000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-34000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-34000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-34000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-29000] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-41500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-41500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-41500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-41500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-41500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-36500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-37000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-42500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-37500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-38000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-43500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-38500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-44000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-44000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-44000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-44000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-44000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-39000] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-47000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-52500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-47500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-48000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-53500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-48500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-49000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-54500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-49500] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-56000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-61500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-56500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-57000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-62500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-57500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-58000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-63500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-58500] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-66000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-71500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-66500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-67000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-72500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-67500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-68000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-73500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-68500] due to args.save_total_limit
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-80500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-80500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-80500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-80500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-80500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-75500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-76000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-81500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-76500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-77000] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82500
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82500/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82500/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82500/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-82500/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-77500] due to args.save_total_limit
# Saving model checkpoint to ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-83000
# Configuration saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-83000/config.json
# Model weights saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-83000/pytorch_model.bin
# tokenizer config file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-83000/tokenizer_config.json
# Special tokens file saved in ../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-83000/special_tokens_map.json
# Deleting older checkpoint [../../models/checkpoints/IKEA_MT_en_GB-da_DK_2022-12-28 17:21:10.616551/checkpoint-78000] due to args.save_total_limit

# %%
trainer.save_model('../../models/en_GB-da_DK/IKEA_MT-en_da_DK_' + time)

# %%
trainer.evaluate
